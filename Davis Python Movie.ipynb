# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# ## Python Review With Movie Data
#
# _Author: Kiefer Katovich and Dave Yerrington (San Francisco)
#
# ---
#
# In this lab, you'll be using the [IMDb](http://www.imdb.com/) `movies` list below as your data set.
#
# This lab is designed to help you practice iteration and functions in particular. The normal questions are more gentle, and the challenge questions are suitable for advanced/expert Python students or those with programming experience.
#
# All of the questions require writing functions and using iteration to solve. You should print out a test of each function you write.
#
#
# ### 1) Load the provided list of `movies` dictionaries.

# %%
# List of movies dictionaries:
movies = [
{
"name": "Usual Suspects", 
"imdb": 7.0,
"category": "Thriller"
},
{
"name": "Hitman",
"imdb": 6.3,
"category": "Action"
},
{
"name": "Dark Knight",
"imdb": 9.0,
"category": "Adventure"
},
{
"name": "The Help",
"imdb": 8.0,
"category": "Drama"
},
{
"name": "The Choice",
"imdb": 6.2,
"category": "Romance"
},
{
"name": "Colonia",
"imdb": 7.4,
"category": "Romance"
},
{
"name": "Love",
"imdb": 6.0,
"category": "Romance"
},
{
"name": "Bride Wars",
"imdb": 5.4,
"category": "Romance"
},
{
"name": "AlphaJet",
"imdb": 3.2,
"category": "War"
},
{
"name": "Ringing Crime",
"imdb": 4.0,
"category": "Crime"
},
{
"name": "Joking muck",
"imdb": 7.2,
"category": "Comedy"
},
{
"name": "What is the name",
"imdb": 9.2,
"category": "Suspense"
},
{
"name": "Detective",
"imdb": 7.0,
"category": "Suspense"
},
{
"name": "Exam",
"imdb": 4.2,
"category": "Thriller"
},
{
"name": "We Two",
"imdb": 7.2,
"category": "Romance"
}
]

# 3.2 Expert. Copy current dict list to a new dictionary list and add a new value
# name 'avgcatrating' to the new dict list to store the average category rating for the 
# respective title. Sort the new dict list first by 'avgcatrating' followed by
# value['imdb'].

# get a list of unique categories.
def CalAveScore(newlist):
    cattype = [] # Initialized empty list to store unique category type.
    for x in range(0,len(newlist)):
        for key, value in newlist[x].items():
            if key == 'category':
                cattype.append(value)
    # create a dict to record number of counts for similar category respectively.
    catcount = {x:cattype.count(x) for x in cattype}
    ct, cc = catcount.keys(), catcount.values()
    # print(ct, cc)
    # compute average rating for each category. Skip for category count = 1 as the
    # average = the 'imdb' rating.
#    for i,j in catcount.items(): # i is category
#        if j > 1: # Compute avg only when category has more than 1 movie
#        print("Average ratings for category " + i + " is", AvgRatings(i))

# Loop through the entire movie list to add another key:value to record average
# ratings for that category. This value is to do the first level sort. 
    for x in range(0,len(newlist)):
        for y, z in newlist[x].items():
            if y == 'category':
                newlist[x]['AvgRating'] = AvgRatings(z)

    cattype = list(set(cattype))
    return cattype


# compute average ratings for each category.
def AvgRatings(cat):
    avgcatscore = 0
    totalcatratings = 0
    catratingscount = 0
    temp = 0 # Variable to hold IMDB score for categories that match selected movie  
    for x in movies:
        for y,z in x.items():
            if y == 'imdb': # Ratings summation for all movies
                temp = z
            if y == 'category'and z == cat: # Ratings summation for similar category
                totalcatratings = totalcatratings + temp
                catratingscount += 1

    avgcatratings = round(totalcatratings / catratingscount,1)
    return avgcatratings


newlist = movies # work on a copied list.
cattype = CalAveScore(newlist) # get a list of unique categories.
print(type(cattype))
print(newlist)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-79-e99a5735778d> in <module>
#     130
#     131 newlist = movies # work on a copied list.
# --> 132 cattype = CalAveScore(newlist) # get a list of unique categories.
#     133 print(type(cattype))
#     134 print(newlist)
#
# <ipython-input-79-e99a5735778d> in CalAveScore(newlist)
#     103 # ratings for that category. This value is to do the first level sort.
#     104     for x in range(0,len(newlist)):
# --> 105         for y, z in newlist[x].items():
#     106             if y == 'category':
#     107                 newlist[x]['AvgRating'] = AvgRatings(z)
#
# RuntimeError: dictionary changed size during iteration

# %% [markdown]
# ---
#
# ### 2) Filtering data by IMDb score.
#
# #### 2.1)
#
# Write a function that:
#
# 1) Accepts a single movie dictionary from the `movies` list as an argument.
# 2) Returns `True` if the IMDb score is greater than 5.5.
#
# #### 2.2 [Challenge])
#
# Write a function that:
#
# 1) Accepts the `movies` list and a specified category.
# 2) Returns `True` if the average score of the category is higher than the average score of all movies.

# %%
# 2.1 Return True for rating > 5.5 or False for rating <= 5.5
def Rating(title):
    for x in range(0,len(movies)):
        for y,z in movies[x].items():
            if title.upper() == str(z).upper(): # Convert to all to upper case
                if movies[x]['imdb'] > 5.5:     # to ease searching
                    return True
                elif movies[x]['imdb'] <= 5.5:
                    return False
    print("Movie not found in system.")

# Testing...
Rating('hitman')


# 2.2 Challenge
def Retrieve(title):
    for x in range(0,len(movies)):
        for y,z in movies[x].items():
            if title.upper() == str(z).upper():
                return movies[x]['category']
    print("Movie not found in system.")
    return False

def AvgRatings(cat):
    avgcatscore = 0
    avgtotalratings = 0
    totalratings = 0
    totalcatratings = 0
    catratingscount = 0
    temp = 0 # Variable to hold IMDB score for categories that match selected movie  
    for x in movies:
        for y,z in x.items():
            if y == 'imdb': # Ratings summation for all movies
                temp = z
                totalratings = totalratings + temp
            if y == 'category'and z == cat: # Ratings summation for similar category
                totalcatratings = totalcatratings + temp
                catratingscount += 1

    avgtotalratings = round(totalratings / len(movies),1)
    avgcatratings = round(totalcatratings / catratingscount,1)

# The following print section is to check whether the logic works. Can be deleted.
    print (y, cat)
    print("Total ratings is,", round(totalratings,1))
    print("Total number of movies in the system is,", len(movies))
    print ("Average ratings is, ", avgtotalratings)

    print("Total " + cat + " category ratings is,", totalcatratings)
    print("Total number of " + cat + " category count is,", catratingscount)
    print ("Average " + cat + " category ratings is,", avgcatratings)
 # End of test section.

    if avgcatratings > avgtotalratings:
        return True
    else:
        return False

# Testing...
# First check whether selected movie is in the system or not.
cat = Retrieve('DETECTIVE')

# If returned value is not False, this mean, selected movie title is in the system.
# Thus can proceed with calling AvgRatings function to compute average ratings for
# the selected category and compare results with average movies ratings.
if cat != False:
    AvgRatings(cat)
# Out:
# category Suspense
# Total ratings is, 97.3
# Total number of movies in the system is, 15
# Average ratings is,  6.5
# Total Suspense category ratings is, 16.2
# Total number of Suspense category count is, 2
# Average Suspense category ratings is, 8.1

# %% [markdown]
# ---
#
# ### 3) Creating subsets by numeric condition.
#
# #### 3.1)
#
# Write a function that:
#
# 1) Accepts the list of movies and a specified IMDb score.
# 2) Returns the sublist of movies that have scores greater than the one specified.
#
# #### 3.2 [Expert])
#
# Write a function that:
#
# 1) Accepts the `movies` list as an argument.
# 2) Returns the `movies` list sorted first by category and then by movie according to category average score and individual IMDb score, respectively.

# %%
# 3.1 Return sublist of movies with higher ratings than user's input
def Retrieve(score):
    hitlist = [] # Initialized empty list to store recommended movies with higher ratings.
    temp = "" # Variable to store movie title temporary as potential hitlist.
    for x in range(0,len(movies)):
        for key, value in movies[x].items():
            if key == 'name':
                temp = value
            if key == 'imdb'and value > score:
                hitlist.append(temp)
    return hitlist

# Testing...
rating = input('Enter ratings for recommended movies (eg. 5.5 or 7) => ')
rating = round(float(rating),1)
hitlist = Retrieve(rating)
print(hitlist)


# For 3.2, refer to the codes in the movie list section right at the top.
# Out:
# Enter ratings for recommended movies (eg. 5.5 or 7) => 6
# ['Usual Suspects', 'Hitman', 'Dark Knight', 'The Help', 'The Choice', 'Colonia', 'Joking muck', 'What is the name', 'Detective', 'We Two']

# %% [markdown]
# ---
#
# ### 4) Creating subsets by string condition.
#
# #### 4.1)
#
# Write a function that:
#
# 1) Accepts the `movies` list and a category name.
# 2) Returns the movie names within that category (case-insensitive!).
# 3) If the category is not in the data, prints a message that says it does not exist and returns `None`.
#
# Recall that, to convert a string to lowercase, you can use:
#
# ```python
# mystring = 'Dumb and Dumber'
# lowercase_mystring = mystring.lower()
# print lowercase_mystring
# 'dumb and dumber'
# ```
#
# #### 4.2 [Challenge])
#
# Write a function that:
#
# 1) Accepts the `movies` list and a "search string."
# 2) Returns a dictionary with the keys `'category'` and `'title'` whose values are lists of categories that contain the search string and titles that contain the search string, respectively (case-insensitive!).

# %%
# Your code here.

# %% [markdown]
# ---
#
# ### 5) Multiple conditions.
#
# #### 5.1)
#
# Write a function that:
#
# 1) Accepts the `movies` list and a "search criteria" variable.
# 2) If the criteria variable is numeric, return a list of movie titles with a score greater than or equal to the criteria.
# 3) If the criteria variable is a string, return a list of movie titles that match that category (case-insensitive!). If there is no match, return an empty list and print an informative message.
#
# #### 5.2 [Expert])
#
# Write a function that:
#
# 1) Accepts the `movies` list and a string search criteria variable.
# 2) The search criteria variable can contain within it:
#   - Boolean operations: `'AND'`, `'OR'`, and `'NOT'` (can have/be lowercase as well, we just capitalized for clarity).
#   - Search criteria specified with the syntax `score=...`, `category=...`, and/or `title=...`, where the `...` indicates what to look for.
#     - If `score` is present, it indicates scores greater than or equal to the value.
#     - For `category` and `title`, the string indicates that the category or title must _contain_ the search string (case-insensitive).
# 3) Return the matches for the search criteria specified.

# %%
# Your code here.
